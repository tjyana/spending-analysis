# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('spending.csv', header = None)
data.head(10)
# Out:
#                           0
# 0                      2/11
# 1            68330 Feb rent
# 2                770 charge
# 3          68330 March rent
# 4                770 charge
# 5         880 lunch torisho
# 6   3580 plants rack amazon
# 7  7980 air purifier amazon
# 8                      2/12
# 9            750 McDonald’s

# %%
data.columns = data.iloc[0]
data
# Out:
# 0                                    2/11
# 0                                    2/11
# 1                          68330 Feb rent
# 2                              770 charge
# 3                        68330 March rent
# 4                              770 charge
# ..                                    ...
# 598    4000, social dinner, tres hermanos
# 599  600, social snacks, what the dickens
# 600                   700, taxi, to Ebisu
# 601                                  7/27
# 602                              Nothing!
#
# [603 rows x 1 columns]

# %%
data.rename(columns={'2/11': 'item'}, inplace=True)
data
# Out:
# 0                                    item
# 0                                    2/11
# 1                          68330 Feb rent
# 2                              770 charge
# 3                        68330 March rent
# 4                              770 charge
# ..                                    ...
# 598    4000, social dinner, tres hermanos
# 599  600, social snacks, what the dickens
# 600                   700, taxi, to Ebisu
# 601                                  7/27
# 602                              Nothing!
#
# [603 rows x 1 columns]

# %%
# check data

print(data.shape)
print(data.isna().sum())
# Out:
# (603, 1)
# 0
# item    0
# dtype: int64

# %%
# create date column 

def date_column(date_str):
    if date_str.replace('/', '').isdigit() == True:
        return date_str
    
data['Date'] = data['item'].apply(date_column)
data
# Out:
# 0                                    item  Date
# 0                                    2/11  2/11
# 1                          68330 Feb rent  None
# 2                              770 charge  None
# 3                        68330 March rent  None
# 4                              770 charge  None
# ..                                    ...   ...
# 598    4000, social dinner, tres hermanos  None
# 599  600, social snacks, what the dickens  None
# 600                   700, taxi, to Ebisu  None
# 601                                  7/27  7/27
# 602                              Nothing!  None
#
# [603 rows x 2 columns]

# %%
# function to fill in the dates for the Nones. forward fill!
data['Date'] = data['Date'].ffill()
data.head(20)
# Out:
# 0                       item  Date
# 0                       2/11  2/11
# 1             68330 Feb rent  2/11
# 2                 770 charge  2/11
# 3           68330 March rent  2/11
# 4                 770 charge  2/11
# 5          880 lunch torisho  2/11
# 6    3580 plants rack amazon  2/11
# 7   7980 air purifier amazon  2/11
# 8                       2/12  2/12
# 9             750 McDonald’s  2/12
# 10        1814 groceries top  2/12
# 11                      2/13  2/13
# 12         283 snacks famima  2/13
# 13        1900 shoes workman  2/13
# 14        540 dinner donmaru  2/13
# 15     300 groceries donmaru  2/13
# 16         200 snacks summit  2/13
# 17      765 groceries summit  2/13
# 18                      2/14  2/14
# 19                   Nothing  2/14

# %%
# how many rows have just the date and no items:

(data['item'] == data['Date']).sum()
# Out:
# 167

# %%
# clear out the date-only rows
# boolean mask
data = data[data['item'] != data['Date']]
data.shape
# Out:
# (436, 2)

# %%
# convert the dates to datetime objects

from datetime import datetime

def add_year(date_str):
    return datetime.strptime(f'{date_str}/2024', '%m/%d/%Y')

data['Date'] = data['Date'].apply(add_year)
data
# Out:
# /tmp/ipykernel_131347/914769.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(add_year)
# 0                                    item       Date
# 1                          68330 Feb rent 2024-02-11
# 2                              770 charge 2024-02-11
# 3                        68330 March rent 2024-02-11
# 4                              770 charge 2024-02-11
# 5                       880 lunch torisho 2024-02-11
# ..                                    ...        ...
# 596          2595, groceries, gyomu super 2024-07-25
# 598    4000, social dinner, tres hermanos 2024-07-26
# 599  600, social snacks, what the dickens 2024-07-26
# 600                   700, taxi, to Ebisu 2024-07-26
# 602                              Nothing! 2024-07-27
#
# [436 rows x 2 columns]

# %% [markdown]
# ### next: parse out amount, item, location

# %%
def split_item(item):
    if ',' in item:
        return item.split(',')
    else: 
        return item.split()

data['item'] = data['item'].apply(split_item)    
data
# Out:
# /tmp/ipykernel_131347/4251038750.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['item'] = data['item'].apply(split_item)
# 0                                        item       Date
# 1                          [68330, Feb, rent] 2024-02-11
# 2                               [770, charge] 2024-02-11
# 3                        [68330, March, rent] 2024-02-11
# 4                               [770, charge] 2024-02-11
# 5                       [880, lunch, torisho] 2024-02-11
# ..                                        ...        ...
# 596          [2595,  groceries,  gyomu super] 2024-07-25
# 598    [4000,  social dinner,  tres hermanos] 2024-07-26
# 599  [600,  social snacks,  what the dickens] 2024-07-26
# 600                   [700,  taxi,  to Ebisu] 2024-07-26
# 602                                [Nothing!] 2024-07-27
#
# [436 rows x 2 columns]

# %%
def parse_items(row):
    price, item, location, details = None, None, None, None
    if len(row) > 0:
        price = row[0]
    if len(row) > 1:
        item = row[1]
    if len(row) > 2:
        location = row[2]
    if len(row) > 3:
        details = row[3]
    return pd.Series([price, item, location, details])

# Apply the function to the 'items' column and create new columns
data[['Price', 'Item', 'Location', 'Details']] = data['item'].apply(parse_items)
# Out:
# /tmp/ipykernel_131347/4063008736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Price', 'Item', 'Location', 'Details']] = data['item'].apply(parse_items)
# /tmp/ipykernel_131347/4063008736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Price', 'Item', 'Location', 'Details']] = data['item'].apply(parse_items)
# /tmp/ipykernel_131347/4063008736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Price', 'Item', 'Location', 'Details']] = data['item'].apply(parse_items)
# /tmp/ipykernel_131347/4063008736.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Price', 'Item', 'Location', 'Details']] = data['item'].apply(parse_items)

# %%
data
# Out:
# 0                                        item       Date     Price  \
# 1                          [68330, Feb, rent] 2024-02-11     68330
# 2                               [770, charge] 2024-02-11       770
# 3                        [68330, March, rent] 2024-02-11     68330
# 4                               [770, charge] 2024-02-11       770
# 5                       [880, lunch, torisho] 2024-02-11       880
# ..                                        ...        ...       ...
# 596          [2595,  groceries,  gyomu super] 2024-07-25      2595
# 598    [4000,  social dinner,  tres hermanos] 2024-07-26      4000
# 599  [600,  social snacks,  what the dickens] 2024-07-26       600
# 600                   [700,  taxi,  to Ebisu] 2024-07-26       700
# 602                                [Nothing!] 2024-07-27  Nothing!
#
# 0              Item           Location Details
# 1               Feb               rent    None
# 2            charge               None    None
# 3             March               rent    None
# 4            charge               None    None
# 5             lunch            torisho    None
# ..              ...                ...     ...
# 596       groceries        gyomu super    None
# 598   social dinner      tres hermanos    None
# 599   social snacks   what the dickens    None
# 600            taxi           to Ebisu    None
# 602            None               None    None
#
# [436 rows x 6 columns]

# %%
data.to_csv('Spending 2.csv')

# %% [markdown]
# ## buncha experimentation

# %%
# data['Date']

def find_date(column):
    for i in range(len(column)):
        if column[i].replace('/', '').isdigit() == True:
            date = column[i]

# %%
def insert_date(column, ):
    while row.replace('/', '').isdigit() == False:
# Out:
#   Cell In [223], line 3
#
#     ^
# SyntaxError: incomplete input

# %%
'2/12'.isdigit()

# %%
'2/12'.replace('/', '')
