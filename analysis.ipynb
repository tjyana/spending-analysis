# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Spending 2.csv')
df
# Out:
#      Unnamed: 0                                            item        Date  \
# 0             1                        ['68330', 'Feb', 'rent']  2024-02-11
# 1             2                               ['770', 'charge']  2024-02-11
# 2             3                      ['68330', 'March', 'rent']  2024-02-11
# 3             4                               ['770', 'charge']  2024-02-11
# 4             5                     ['880', 'lunch', 'torisho']  2024-02-11
# ..          ...                                             ...         ...
# 431         596          ['2595', ' groceries', ' gyomu super']  2024-07-25
# 432         598    ['4000', ' social dinner', ' tres hermanos']  2024-07-26
# 433         599  ['600', ' social snacks', ' what the dickens']  2024-07-26
# 434         600                   ['700', ' taxi', ' to Ebisu']  2024-07-26
# 435         602                                    ['Nothing!']  2024-07-27
#
#         Price            Item           Location Details
# ...
